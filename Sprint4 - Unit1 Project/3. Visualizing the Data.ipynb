# %%
import pandas as pd
import ipywidgets as widgets
import numpy as np
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import matplotlib.ticker as tkr

from matplotlib.dates import DateFormatter, AutoDateFormatter, AutoDateLocator
from google.colab import drive
from os import listdir
from scipy import stats
from IPython.display import display
from google.colab import drive
from os import listdir

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataPath = '/content/drive/My Drive/Colab Notebooks/Sprint4 - Unit1 Project/DataSets/'
viewsets = sorted(listdir(dataPath))
viewsets
# Out:
# ['DOBComplaintsDesc',
#  'DOBViolationsDesc',
#  'DOB_Complaints_Received',
#  'DOB_ECB_Violations',
#  'DOB_Violations',
#  'HPD_Complaint_Problems',
#  'HPD_Maintenance_Code_Complaints.csv',
#  'HPD_Maintenance_Code_Violations.csv',
#  'Housing_Litigations',
#  'Zip_MedianRentalPrice_1Bedroom.csv',
#  'Zip_MedianRentalPrice_2Bedroom.csv',
#  'Zip_MedianRentalPrice_3Bedroom.csv',
#  'Zip_MedianRentalPrice_4Bedroom.csv',
#  'Zip_MedianRentalPrice_Studio.csv',
#  'dfZil1Sub.csv',
#  'dfZil2Sub.csv',
#  'dfZil3Sub.csv',
#  'dfZil4Sub.csv',
#  'dfZilStuSub.csv']

# %%
dfZ0 = pd.read_csv(dataPath+'dfZilStuSub.csv')
dfZ0.head()
# Out:
#    RegionName  2016-10  2016-11  2016-12  ...  2019-06  2019-07  2019-08  2019-09
# 0       10025   2600.0   2550.0   2400.0  ...   2700.0   2800.0   2695.0   2697.5
# 1       10023   2685.0   2675.0   2600.0  ...   2707.5   2700.0   2765.0   2850.0
# 2       10002   2297.5   2200.0   2195.0  ...   2500.0   2300.0   2495.0   2344.0
# 3       10016   2500.0   2550.0   2450.0  ...   2850.0   2850.0   2800.0   2817.0
# 4       10029   2850.0   2800.0   2837.5  ...   2700.0   2750.0   2850.0   2850.0
#
# [5 rows x 37 columns]

# %%
testDf = dfZ0
newHeader = list(testDf['RegionName'])
# testDf = testDf.T[1:]
# testDf = testDf[1:]
# testDf.columns = newHeader
testDf.head()
# Out:
#    RegionName  2016-10  2016-11  2016-12  ...  2019-06  2019-07  2019-08  2019-09
# 0       10025   2600.0   2550.0   2400.0  ...   2700.0   2800.0   2695.0   2697.5
# 1       10023   2685.0   2675.0   2600.0  ...   2707.5   2700.0   2765.0   2850.0
# 2       10002   2297.5   2200.0   2195.0  ...   2500.0   2300.0   2495.0   2344.0
# 3       10016   2500.0   2550.0   2450.0  ...   2850.0   2850.0   2800.0   2817.0
# 4       10029   2850.0   2800.0   2837.5  ...   2700.0   2750.0   2850.0   2850.0
#
# [5 rows x 37 columns]

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
zipCodes =	[10001, 10002, 10003, 10004, 10005, 10006, 10007, 10009, 10010,
             10011, 10012, 10013, 10014, 10016, 10017, 10018, 10019, 10020,
             10021, 10022, 10023, 10024, 10025, 10026, 10027, 10028, 10029,
             10030, 10031, 10032, 10033, 10034, 10035, 10036, 10037, 10038,
             10039, 10040, 10065, 10075, 10128, 10280, 10282]


zips1 = [10034, 10040, 10033, 10032, 10039, 10031]
zips2 = [10030, 10037, 10027, 10026]
zips3 = [10035, 10029]
zips4 = [10025, 10024, 10023]
zips5 = [10128, 10028, 10021, 10065, 10075]
zips6 = [10019, 10020, 10022, 10017, 10036, 10018, 10016, 10001]
zips7 = [10010, 10011, 10003, 10009, 10014, 10012]
zips8 = [10002, 10013, 10038, 10007, 10048, 10005, 10006, 10004, 10280, 10282]

zdfs = {
    'zips1': 'Uptown',
    'zips2': 'Harlem',
    'zips3': 'EastHarlem',
    'zips4': 'UWS',
    'zips5': 'UES',
    'zips6': 'Midtown',
    'zips7': 'Chel-E.Vill',
    'zips8': 'Downtown'
    }

allZips = sorted(zips1+zips2+zips3+zips4+zips5+zips6+zips7+zips8)

diff = [x for x in zipCodes if x not in allZips]
print(diff)
# Out:
# []

# %%
dataPath = '/content/drive/My Drive/Colab Notebooks/Sprint4 - Unit1 Project/DataSets/'
viewsets = sorted(listdir(dataPath))
viewsets
# Out:
# ['DOBComplaintsDesc',
#  'DOBViolationsDesc',
#  'DOB_Complaints_Received',
#  'DOB_ECB_Violations',
#  'DOB_Violations',
#  'HPD_Complaint_Problems',
#  'HPD_Maintenance_Code_Complaints.csv',
#  'HPD_Maintenance_Code_Violations.csv',
#  'Housing_Litigations',
#  'Zip_MedianRentalPrice_1Bedroom.csv',
#  'Zip_MedianRentalPrice_2Bedroom.csv',
#  'Zip_MedianRentalPrice_3Bedroom.csv',
#  'Zip_MedianRentalPrice_4Bedroom.csv',
#  'Zip_MedianRentalPrice_Studio.csv',
#  'dfZil1Sub.csv',
#  'dfZil2Sub.csv',
#  'dfZil3Sub.csv',
#  'dfZil4Sub.csv',
#  'dfZilStuSub.csv']

# %%
dfZ0 = pd.read_csv(dataPath+'dfZilStuSub.csv')
dfZ1 = pd.read_csv(dataPath+'dfZil1Sub.csv')
dfZ2 = pd.read_csv(dataPath+'dfZil2Sub.csv')
dfZ3 = pd.read_csv(dataPath+'dfZil3Sub.csv')
dfZ0.head()
# Out:
#    RegionName  2016-10  2016-11  2016-12  ...  2019-06  2019-07  2019-08  2019-09
# 0       10025   2600.0   2550.0   2400.0  ...   2700.0   2800.0   2695.0   2697.5
# 1       10023   2685.0   2675.0   2600.0  ...   2707.5   2700.0   2765.0   2850.0
# 2       10002   2297.5   2200.0   2195.0  ...   2500.0   2300.0   2495.0   2344.0
# 3       10016   2500.0   2550.0   2450.0  ...   2850.0   2850.0   2800.0   2817.0
# 4       10029   2850.0   2800.0   2837.5  ...   2700.0   2750.0   2850.0   2850.0
#
# [5 rows x 37 columns]

# %%
def reshapeZil(df):
  newHeader = list(df['RegionName'])
  df = df.T[1:]
  # df = df.fillna(method='bfill')
  df.columns = newHeader
  return df

# %%
dfZ0 = reshapeZil(dfZ0)
dfZ1 = reshapeZil(dfZ1)
dfZ2 = reshapeZil(dfZ2)
dfZ3 = reshapeZil(dfZ3)

# %%
dfZ2.head()
# Out:
#           10025   10023   10002   10016  ...   10005   10007   10006   10004
# 2016-10  3500.0  4800.0  3200.0  4200.0  ...  5192.0  6870.5     NaN  5495.0
# 2016-11  3500.0  4875.0  3395.0  4200.0  ...  5250.0  6995.0     NaN  5422.5
# 2016-12  3500.0  4800.0  3199.5  4195.0  ...  5050.0  6595.0     NaN  5350.0
# 2017-01  3500.0  4800.0  3200.0  4200.0  ...  5294.0  7197.5  4750.0  5495.0
# 2017-02  3500.0  4900.0  3300.0  4250.0  ...  5507.5  7495.0  4940.0  5390.0
#
# [5 rows x 38 columns]

# %%
sns.set()
f, ax = plt.subplots(figsize=(12,8))
data = pd.DataFrame(dfZ2, columns = zips1)

palette = dict(zip(data.columns.unique(),
                   sns.color_palette('cubehelix', 8)))

sns.lineplot(palette=palette, data=data)
ax.set(xlabel='Date', ylabel='Price',
       title='Median monthly rent for\na 2br in Central Harlem')

ax.xaxis.set_major_locator(tkr.LinearLocator())

plt.show()

# %%
zcode = widgets.Dropdown(options=zipCodes)

# %%
def drawPlot(zcode):
  with output:
    output.clear_output()
    index = dfZ0.index

    #####
    sns.set()
    f, ax = plt.subplots(figsize=(12,8))
    
    sns.lineplot(data=dfZ0[zcode], ax=ax, color='b', legend='brief')
    sns.lineplot(data=dfZ1[zcode], ax=ax, color='r', legend='brief')
    sns.lineplot(data=dfZ2[zcode], ax=ax, color='g', legend='brief')
    # sns.lineplot(data=dfZ3[zcode], ax=ax, color='k', legend='brief')

    title = 'Median Monthly Rent in zip code '+str(zcode)

    ax.set(xlabel='Date', ylabel='Price',
          title=title)

    ax.xaxis.set_major_locator(tkr.LinearLocator())

    plt.show()
    #####

output = widgets.interactive_output(drawPlot, {'zcode': zcode})

widgets.VBox([zcode, output])
